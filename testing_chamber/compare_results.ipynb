# %%
import pandas as pd

df = pd.read_csv("../results_comparison_20250917_064315.csv")
df = df.dropna()
df = df.drop(columns=["similarity_improvement", "average_improvement"])
df
# Out:
#    locale  baseline  similarity   average
# 0   af-ZA  0.850370    0.673840  0.683927
# 1   am-ET  0.815064    0.514795  0.505380
# 2   ar-SA  0.807666    0.468393  0.573638
# 3   az-AZ  0.843309    0.679892  0.671486
# 4   bn-BD  0.843981    0.632145  0.615669
# 5   ca-ES  0.860121    0.751513  0.760256
# 6   cy-GB  0.828178    0.430397  0.426026
# 7   da-DK  0.861130    0.784802  0.797243
# 8   de-DE  0.854741    0.710827  0.738399
# 9   el-GR  0.849361    0.666443  0.674176
# 10  en-US  0.876933    0.792872  0.807666
# 11  es-ES  0.852724    0.773705  0.776732
# 12  fa-IR  0.864829    0.732683  0.698722
# 13  fi-FI  0.854405    0.757229  0.733692
# 14  fr-FR  0.872226    0.772360  0.773369
# 15  hi-IN  0.843309    0.686281  0.675521
# 16  hu-HU  0.859449    0.660726  0.666779
# 17  hy-AM  0.836247    0.566577  0.607935
# 18  id-ID  0.860457    0.711500  0.726631
# 19  is-IS  0.847007    0.600202  0.601547
# 20  it-IT  0.863820    0.749832  0.753867
# 21  ja-JP  0.859449    0.666443  0.653665
# 22  jv-ID  0.822125    0.486886  0.456624
# 23  ka-GE  0.800605    0.559516  0.542703
# 24  km-KH  0.786483    0.527236  0.524546
# 25  kn-IN  0.843981    0.565905  0.593141
# 26  ko-KR  0.851715    0.634163  0.614660
# 27  lv-LV  0.848016    0.660726  0.656355
# 28  ml-IN  0.848689    0.668124  0.660390
# 29  mn-MN  0.843981    0.564560  0.547075
# 30  ms-MY  0.858104    0.627774  0.629455
# 31  my-MM  0.828514    0.582044  0.587424
# 32  nb-NO  0.867182    0.789845  0.767317
# 33  nl-NL  0.868863    0.783793  0.782448
# 34  pl-PL  0.856422    0.720242  0.699395
# 35  pt-PT  0.866174    0.778413  0.772360
# 36  ro-RO  0.854741    0.750504  0.774378
# 37  ru-RU  0.867518    0.672495  0.738736
# 40  sw-KE  0.806321    0.431069  0.435777
# 41  ta-IN  0.838937    0.620040  0.624412
# 42  te-IN  0.833894    0.633490  0.630464
# 44  tl-PH  0.842636    0.503699  0.597176
# 45  tr-TR  0.860457    0.700740  0.689644
# 46  ur-PK  0.830868    0.588769  0.616678
# 47  vi-VN  0.864156    0.649966  0.649966

# %%
import os
import re

def find_locale_for_merge(locale: str) -> list:
    with open(os.path.join("..", "merged_models", f"similarity_merge_{locale}", "merge_details.txt")) as f:
        text = f.read()

    local_pattern = re.compile(r"^\s*-\s*Locale: \s*([a-zA-Z]{2}-[a-zA-Z]{2})$", re.MULTILINE)
    found_locales = local_pattern.findall(text)

    return found_locales

find_locale_for_merge("vi-VN")
# Out:
# ['km-KH', 'th-TH', 'id-ID', 'jv-ID', 'ms-MY']

# %%
df_nxn = pd.read_csv("../nxn_results/nxn_eval_20250915_101911/evaluation_matrix.csv", index_col=0)
df_nxn = df_nxn.dropna()
df_nxn
# Out:
# is-IS  0.640551  0.566913  0.650639  0.517485  0.663080  0.684264  0.646940
# it-IT  0.681574  0.578682  0.680901  0.541695  0.726631  0.728312  0.696705
# ja-JP  0.673167  0.514795  0.711163  0.532280  0.689307  0.756557  0.718225
# jv-ID  0.618695  0.514122  0.602219  0.441493  0.642905  0.634835  0.610625
# ka-GE  0.614660  0.545057  0.638534  0.550101  0.642569  0.665770  0.632145
# km-KH  0.644923  0.482179  0.612979  0.470074  0.640215  0.681237  0.629119
# kn-IN  0.667115  0.569603  0.691997  0.614660  0.695024  0.716207  0.666779
# ko-KR  0.664761  0.455952  0.634835  0.449227  0.589106  0.706120  0.684600
# lv-LV  0.645259  0.540350  0.655346  0.547747  0.663753  0.678547  0.656691
# ml-IN  0.661399  0.553800  0.683255  0.603900  0.657364  0.706792  0.668460
# mn-MN  0.647949  0.492266  0.681237  0.537323  0.664425  0.682919  0.655346
# ms-MY  0.693342  0.562542  0.674849  0.546402  0.721251  0.706792  0.682919
# my-MM  0.648285  0.511769  0.649294  0.539005  0.609617  0.663753  0.642905
# nb-NO  0.716880  0.616342  0.740081  0.584734  0.740081  0.757566  0.722932
# nl-NL  0.693006  0.604237  0.727976  0.549428  0.713853  0.725958  0.707465
# pl-PL  0.686954  0.579354  0.704102  0.542367  0.716207  0.736046  0.689307
# pt-PT  0.690652  0.603900  0.709482  0.552791  0.714526  0.744788  0.707801
# ro-RO  0.681910  0.560188  0.713853  0.551782  0.702085  0.720915  0.688971
# ru-RU  0.697377  0.549428  0.686281  0.541695  0.686617  0.728985  0.690316
# sw-KE  0.529590  0.453262  0.503699  0.379623  0.484533  0.497646  0.484869
# ta-IN  0.682919  0.560861  0.711836  0.609953  0.695696  0.723941  0.704775
# te-IN  0.657028  0.539341  0.695360  0.609953  0.657700  0.722260  0.665770
# tl-PH  0.646268  0.841627  0.680565  0.549092  0.669805  0.667787  0.645595
# tr-TR  0.679556  0.584398  0.860794  0.601547  0.703093  0.725622  0.681574
# ur-PK  0.658709  0.553127  0.685945  0.831204  0.664089  0.714526  0.687626
# vi-VN  0.688971  0.509751  0.644586  0.484533  0.864492  0.724950  0.674512
# zh-TW  0.688299  0.510424  0.648958  0.502017  0.664425  0.829523  0.834230
#
# [46 rows x 52 columns]

# %%
scores_available = []
examples_locales_for_merge = find_locale_for_merge("vi-VN")
for locale in examples_locales_for_merge:
    if locale in df_nxn.index:
        scores_available.append(locale)
print(scores_available)
# Out:
# ['km-KH', 'id-ID', 'jv-ID', 'ms-MY']

# %%
df[df["locale"] == locales][["baseline", "similarity", "average"]].squeeze(0)
# Out:
# baseline      0.864156
# similarity    0.649966
# average       0.649966
# Name: 47, dtype: float64

# %%
locales = "cy-GB"
scores_available = []
examples_locales_for_merge = find_locale_for_merge(locales)
for locale in examples_locales_for_merge:
    if locale in df_nxn.index:
        scores_available.append(locale)
benchmark = pd.concat([df_nxn[locales][scores_available], df[df["locale"] == locales][["baseline", "similarity", "average"]].squeeze(0)])
benchmark
# Out:
# ca-ES         0.377942
# el-GR         0.391392
# it-IT         0.363147
# pl-PL         0.398117
# pt-PT         0.398790
# baseline      0.828178
# similarity    0.430397
# average       0.426026
# dtype: float64

# %%
    df_nxn[locales][find_locale_for_merge(locales)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 locales = "vi-VN"
# ----> 2 df_nxn[locales][find_locale_for_merge("vi-VN")]
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/series.py:1162, in Series.__getitem__(self, key)
#    1159     key = np.asarray(key, dtype=bool)
#    1160     return self._get_rows_with_mask(key)
# -> 1162 return self._get_with(key)
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/series.py:1203, in Series._get_with(self, key)
#    1200         return self.iloc[key]
#    1202 # handle the dup indexing case GH#4246
# -> 1203 return self.loc[key]
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/Python_project/MergingUriel/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['th-TH'] not in index"
