# %%
import pandas as pd

df = pd.read_csv("../results_comparison_20250911_110343.csv")
# df = df[df["locale"] != "km-KH"]
df
# Out:
#    locale  baseline  similarity   average  similarity_improvement  \
# 0   af-ZA  0.850370    0.673840  0.683927               -0.176530
# 1   am-ET  0.815064    0.514795  0.505380               -0.300269
# 2   ar-SA  0.807666    0.468393  0.573638               -0.339274
# 3   az-AZ  0.843309    0.679892  0.671486               -0.163416
# 4   bn-BD  0.843981    0.632145  0.615669               -0.211836
# 5   ca-ES  0.860121    0.751513  0.760256               -0.108608
# 6   cy-GB  0.828178    0.430397  0.426026               -0.397781
# 7   da-DK  0.861130    0.784802  0.797243               -0.076328
# 8   de-DE  0.854741    0.710827  0.738399               -0.143914
# 9   el-GR  0.849361    0.666443  0.674176               -0.182919
# 10  en-US  0.876933    0.792872  0.807666               -0.084062
# 11  es-ES  0.852724    0.773705  0.776732               -0.079018
# 12  fa-IR  0.864829    0.732683  0.698722               -0.132145
# ...

# %%
# Out:
#    locale  baseline  similarity  average  similarity_improvement  \
# 24  km-KH  0.786483         NaN      NaN                     NaN
#
#     average_improvement
# 24                  NaN
